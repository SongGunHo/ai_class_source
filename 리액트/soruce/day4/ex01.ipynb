# %%
pip install numpy
# Out:
# ...
#   Using cached numpy-2.3.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Using cached numpy-2.3.0-cp312-cp312-win_amd64.whl (12.7 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

perch_length = np.array(
    [8.4, 13.7, 15.0, 16.2, 17.4, 18.0, 18.7, 19.0, 19.6, 20.0,
     21.0, 21.0, 21.0, 21.3, 22.0, 22.0, 22.0, 22.0, 22.0, 22.5,
     22.5, 22.7, 23.0, 23.5, 24.0, 24.0, 24.6, 25.0, 25.6, 26.5,
     27.3, 27.5, 27.5, 27.5, 28.0, 28.7, 30.0, 32.8, 34.5, 35.0,
     36.5, 36.0, 37.0, 37.0, 39.0, 39.0, 39.0, 40.0, 40.0, 40.0,
     40.0, 42.0, 43.0, 43.0, 43.5, 44.0]
     )
perch_weight = np.array(
    [5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0,
     110.0, 115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0,
     130.0, 150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0,
     197.0, 218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0,
     514.0, 556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0,
     820.0, 850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0,
     1000.0, 1000.0]
     )

# %%
pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.10.3-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.2-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.58.2-cp312-cp312-win_amd64.whl.metadata (108 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# ...
#   Using cached pillow-11.2.1-cp312-cp312-win_amd64.whl.metadata (9.1 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached matplotlib-3.10.3-cp312-cp312-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.2-cp312-cp312-win_amd64.whl (223 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.58.2-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Using cached pillow-11.2.1-cp312-cp312-win_amd64.whl (2.7 MB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# ...
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
perch_length.shape
# Out:
# (56,)

# %%
pip install scikit-learn
# Out:
# ...
#   Using cached scikit_learn-1.7.0-cp312-cp312-win_amd64.whl.metadata (14 kB)
# ...
#   Using cached scipy-1.15.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.7.0-cp312-cp312-win_amd64.whl (10.7 MB)
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Using cached scipy-1.15.3-cp312-cp312-win_amd64.whl (41.0 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# ...
#
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
train_input , test_input , train_target , train_input =  train_test_split(
     perch_weight, test_size=0.2 , random_state=42 
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 train_input , test_input , train_target , train_input =  train_test_split(
#       2      perch_weight, test_size=0.2 , random_state=42
#       3 )
#
# ValueError: not enough values to unpack (expected 4, got 2)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knr = KNeighborsRegressor()
knr.fit(train_input, train_target)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 knr = KNeighborsRegressor()
# ----> 2 knr.fit(train_input, train_target)
#
# NameError: name 'train_input' is not defined

# %%
print("훈련세트 score", knr.score(train_input, train_target))
print("훈련세트 score", knr.score(test_input, test_target))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 print("훈련세트 score", knr.score(train_input, train_target))
#       2 print("훈련세트 score", knr.score(test_input, test_target))
#
# NameError: name 'train_input' is not defined

# %%
# 과소 적합 상태 - 학습을 더시키거나 모델의 복잡성를 증가 
knr =KNeighborsRegressor(n_neighbors=3)


knr.fit(train_target, train_input)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 5
#       1 # 과소 적합 상태 - 학습을 더시키거나 모델의 복잡성를 증가
#       2 knr =KNeighborsRegressor(n_neighbors=3)
# ----> 5 knr.fit(train_target, train_input)
#
# NameError: name 'train_target' is not defined

# %%
print("훈련세트 score", knr.score(train_input, train_target))
print("훈련세트 score", knr.score(test_input, test_target))

# %%
knr.predict([[38]]) #
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 knr.predict([[38]]) #
#
# File c:\Users\admin\Desktop\송근호\리액트\soruce\.venv\Lib\site-packages\sklearn\neighbors\_regression.py:243, in KNeighborsRegressor.predict(self, X)
#     225 """Predict the target for the provided data.
#     226
#     227 Parameters
#    (...)    238     Target values.
#     239 """
#     240 if self.weights == "uniform":
#     241     # In that case, we do not need the distances to perform
#     242     # the weighting so we do not compute them.
# --> 243     neigh_ind = self.kneighbors(X, return_distance=False)
#     244     neigh_dist = None
#     245 else:
#
# File c:\Users\admin\Desktop\송근호\리액트\soruce\.venv\Lib\site-packages\sklearn\neighbors\_base.py:815, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
# ...
