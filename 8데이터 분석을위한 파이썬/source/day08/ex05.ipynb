# %%
# !pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in c:\users\admin\desktop\송근호\8데이터 분석을위한 파이썬\source\basic\lib\site-packages (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\desktop\송근호\8데이터 분석을위한 파이썬\source\basic\lib\site-packages (from BeautifulSoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\admin\desktop\송근호\8데이터 분석을위한 파이썬\source\basic\lib\site-packages (from BeautifulSoup4) (4.13.2)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
response = requests.get("https://news.naver.com/section/105")
html  = bs(response.text, "html.parser")

# %%
#titles = html.find("strong")
titles = html.find_all("strong")
titles= html.find_all(class_='sa_text_strong')
titles
# Out:
# [<strong class="sa_text_strong">‘이산화탄소를 화학소재로’…오형석 KIST 연구원, 이달의 과학기술인상 수상</strong>,
#  <strong class="sa_text_strong">2030년 6G 시대 대비…ETRI, 6G 인사이트 백서 발간</strong>,
#  <strong class="sa_text_strong">카카오-KISA, 중소사업자 대상 개인정보보호 교육 진행</strong>,
#  <strong class="sa_text_strong">콘진원, '2025년 전국 장애학생 e페스티벌' 지역 예선 개막</strong>,
#  <strong class="sa_text_strong">삼성 '갤럭시 Z폴드 7' 실루엣 공개…'울트라' 더했다</strong>,
#  <strong class="sa_text_strong">KT·LGU+는 해킹 '이상무'…당국, 추가 현장 점검 지속</strong>,
#  <strong class="sa_text_strong">총선 인재로 엔씨 출신 영입했던 이재명…게임 업계 기대감↑</strong>,
#  <strong class="sa_text_strong">지질연, 식생 훼손 없이도 비탈면 붕괴 방지용 콘크리트 시공</strong>,
#  <strong class="sa_text_strong">이재명 정부 첫 국무총리에 김민석…국정원장 이종석·비서실장 강훈식</strong>,
#  <strong class="sa_text_strong">슬림 디자인에 울트라급 성능? 삼성전자 '갤럭시Z폴드7' 티저 공개</strong>,
#  <strong class="sa_text_strong">AI 반도체 강국 외친 李, 업계선 ‘긍정평가’… 현실성엔 ‘물음표’ [이재명 시대]</strong>,
#  <strong class="sa_text_strong">폭증하는 반도체 제조 데이터…'CPU→GPU' 전환 시도</strong>,
#  <strong class="sa_text_strong">KT·LGU+, 1차 서버 보안점검 종료…"현재까지 특이점 없어"</strong>,
#  <strong class="sa_text_strong">일본 기업, 세계 2번째 민간 달 착륙 성공할까…모레 ‘고 투 더 문’</strong>,
#  <strong class="sa_text_strong">‘민원 사주’ 의혹 류희림 방심위원장 사직서 40일 만에 재가</strong>,
#  <strong class="sa_text_strong">[현장] 車·원전·방산 SW 검증 강자 슈어소프트테크, AI 시장 겨냥한 新무기 꺼냈다</strong>,
#  <strong class="sa_text_strong">한의협 "이재명 대통령, 한의약으로 국민건강 돌보게 해달라”</strong>,
#  <strong class="sa_text_strong">이훈기 의원, SK 최태원 회장에 ‘위약금 면제’ 확답 받는다</strong>,
#  <strong class="sa_text_strong">'중국 탓'에 줄었던 엔비디아 시총, '중국 덕'에 세계 1위 탈환</strong>,
#  <strong class="sa_text_strong">새 정부, “세계 최강 AI 인프라 구축”…첨단GPU 탑재 ‘AIDC’ 정책 기대감</strong>,
#  <strong class="sa_text_strong">사람 뇌 닮은 시각 센서 등장… 로봇 사물 인식 정확도 87%로 끌어올려</strong>,
#  <strong class="sa_text_strong">"나 교체하면 불륜 폭로" 사람 협박한 AI [Global]</strong>,
#  <strong class="sa_text_strong">불길 잡혔던 '플랫폼법'...새 정부서 불씨 살까</strong>,
#  <strong class="sa_text_strong">'스텔라 블레이드' PC 데모 흥행... 출시 전부터 기대감 급상승</strong>,
#  <strong class="sa_text_strong">'이재명 시대' 맞이한 이진숙…방통위 어디로</strong>,
#  <strong class="sa_text_strong">'개인정보 보호' 강조한 이재명…SKT, '역대급 과징금' 파장은?</strong>,
#  <strong class="sa_text_strong">서울아산병원, '중국 명문' 칭화대 SOS에 中 건너가 생체 간이식</strong>,
#  <strong class="sa_text_strong">“로봇팔이 물건 줍고 미스트 뿜어 목욕” 5년내 돌봄로봇 상용화… “쉰다는 개념”의 육아휴직 명칭 바꾼다 [AI 프리즘*신입 직장인 뉴스]</strong>,
#  <strong class="sa_text_strong">이재명 정부 ‘디지털 브레인’ 전면 부상… AI·콘텐츠 정책 주도권 잡는다</strong>,
#  <strong class="sa_text_strong">소아청소년 병원들 "지금부터 진짜 K-소아의료 만들어 달라"</strong>,
#  <strong class="sa_text_strong">이재명 정부, 통신비 세액공제-전국민 안심데이터 도입 탄력 기대</strong>,
#  <strong class="sa_text_strong">순식간에 ‘상전벽해’…우주서 본 알프스 빙하 붕괴로 초토화된 마을 [지구를 보다]</strong>,
#  <strong class="sa_text_strong">SKT 유심교체 600만 돌파…KT·LGU+로 이동 50만 육박</strong>,
#  <strong class="sa_text_strong">李, 총리 김민석 의원·국정원장 이종석 전 장관 지명</strong>,
#  <strong class="sa_text_strong">[닻올린 이재명 정부] '5000만원 풀뿌리 연구'부터 살려야…출연연 기관장 임기 일치될까</strong>,
#  <strong class="sa_text_strong">'셀프민원 의혹' 류희림 방심위원장, 대선 당일 사직서 수리</strong>,
#  <strong class="sa_text_strong">마이크론 “모바일용 6세대 D램 샘플 업계 첫 출하”</strong>,
#  <strong class="sa_text_strong">"갤럭시Z폴드 7, 화면 둘 다 커진다"</strong>,
#  <strong class="sa_text_strong">‘오픈AI 축출 사태’가 영화로···올트먼 CEO 역에 앤드루 가필드 물망</strong>,
#  <strong class="sa_text_strong">"수십개 파장으로 운동 중에도 정확·연속 혈압 측정 거뜬하죠"</strong>,
#  <strong class="sa_text_strong">[이재명 시대] DJ 초고속인터넷 정책 AI 버전 찾아내야</strong>,
#  <strong class="sa_text_strong">"갤럭시Z플립 7·폴드 7에 갤럭시워치8까지"…언팩 앞두고 신제품 사양 대거 유출</strong>,
#  <strong class="sa_text_strong">우본, 중증질환 진단 시 사망보험금 선지급 등 보장 확대한 보험 2종 출시</strong>,
#  <strong class="sa_text_strong">“이산화탄소 1년에 500톤씩 자원화”…LG화학 손잡고 주도권 노린다 [이달의 과기인상]</strong>]

# %%
# headline = html.find(class_='as_section_headline')
#headline = html.find(attrs={"data-template-id": "SECTION_HEADLINE", "class": "as_headline"})
headline = html.select_one("div.as_headline[data-template-id='SECTION_HEADLINE']")
#titles = headline.find_all(class_='sa_text_strong')
titles = headline.select(".sa_text_strong")
for title in titles:
    print(title.get_text())
# Out:
# ‘이산화탄소를 화학소재로’…오형석 KIST 연구원, 이달의 과학기술인상 수상
# 2030년 6G 시대 대비…ETRI, 6G 인사이트 백서 발간
# 카카오-KISA, 중소사업자 대상 개인정보보호 교육 진행
# 콘진원, '2025년 전국 장애학생 e페스티벌' 지역 예선 개막
# 삼성 '갤럭시 Z폴드 7' 실루엣 공개…'울트라' 더했다
# KT·LGU+는 해킹 '이상무'…당국, 추가 현장 점검 지속
# 총선 인재로 엔씨 출신 영입했던 이재명…게임 업계 기대감↑
# 지질연, 식생 훼손 없이도 비탈면 붕괴 방지용 콘크리트 시공

# %%
from urllib.request import urlretrieve

path = "C:/web_images/"

images = headline.find_all('img')
for i, image in enumerate(images):
    image_url = image.attrs['data-src']
    urlretrieve(image_url, f"{path}{i}.jpg")

# %%
hyperlinks = headline.find_all(class_="sa_text_title")
for hyperlink in hyperlinks:
   link = hyperlink.attrs['href']
   print(link, hyperlink.attrs)
# Out:
# https://n.news.naver.com/mnews/article/119/0002964638 {'href': 'https://n.news.naver.com/mnews/article/119/0002964638', 'class': ['sa_text_title', '_NLOG_IMPRESSION'], 'data-clk': 'itn.clart', 'data-imp-gdid': '8812A0A8_000000000000000002964638', 'data-imp-url': 'https://n.news.naver.com/mnews/article/119/0002964638', 'data-imp-index': '1'}
# https://n.news.naver.com/mnews/article/016/0002480317 {'href': 'https://n.news.naver.com/mnews/article/016/0002480317', 'class': ['sa_text_title', '_NLOG_IMPRESSION'], 'data-clk': 'itn.clart', 'data-imp-gdid': '8800010E_000000000000000002480317', 'data-imp-url': 'https://n.news.naver.com/mnews/article/016/0002480317', 'data-imp-index': '2'}
# https://n.news.naver.com/mnews/article/215/0001211500 {'href': 'https://n.news.naver.com/mnews/article/215/0001211500', 'class': ['sa_text_title', '_NLOG_IMPRESSION'], 'data-clk': 'itn.clart', 'data-imp-gdid': '88000149_000000000000000001211500', 'data-imp-url': 'https://n.news.naver.com/mnews/article/215/0001211500', 'data-imp-index': '3'}
# https://n.news.naver.com/mnews/article/052/0002201579 {'href': 'https://n.news.naver.com/mnews/article/052/0002201579', 'class': ['sa_text_title', '_NLOG_IMPRESSION'], 'data-clk': 'itn.clart', 'data-imp-gdid': '880000AF_000000000000000002201579', 'data-imp-url': 'https://n.news.naver.com/mnews/article/052/0002201579', 'data-imp-index': '4'}
# https://n.news.naver.com/mnews/article/003/0013284695 {'href': 'https://n.news.naver.com/mnews/article/003/0013284695', 'class': ['sa_text_title', '_NLOG_IMPRESSION'], 'data-clk': 'itn.clart', 'data-imp-gdid': '88000127_000000000000000013284695', 'data-imp-url': 'https://n.news.naver.com/mnews/article/003/0013284695', 'data-imp-index': '5'}
# https://n.news.naver.com/mnews/article/015/0005140435 {'href': 'https://n.news.naver.com/mnews/article/015/0005140435', 'class': ['sa_text_title', '_NLOG_IMPRESSION'], 'data-clk': 'itn.clart', 'data-imp-gdid': '88000107_000000000000000005140435', 'data-imp-url': 'https://n.news.naver.com/mnews/article/015/0005140435', 'data-imp-index': '6'}
# https://n.news.naver.com/mnews/article/008/0005203300 {'href': 'https://n.news.naver.com/mnews/article/008/0005203300', 'class': ['sa_text_title', '_NLOG_IMPRESSION'], 'data-clk': 'itn.clart', 'data-imp-gdid': '880000C2_000000000000000005203300', 'data-imp-url': 'https://n.news.naver.com/mnews/article/008/0005203300', 'data-imp-index': '7'}
# https://n.news.naver.com/mnews/article/001/0015430969 {'href': 'https://n.news.naver.com/mnews/article/001/0015430969', 'class': ['sa_text_title', '_NLOG_IMPRESSION'], 'data-clk': 'itn.clart', 'data-imp-gdid': '880000D8_000000000000000015430969', 'data-imp-url': 'https://n.news.naver.com/mnews/article/001/0015430969', 'data-imp-index': '8'}
