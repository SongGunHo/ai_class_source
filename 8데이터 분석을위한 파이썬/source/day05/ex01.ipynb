# %%
import sys
sys.path.append("C:/my_module")

# %%
from game.graphic import echo_test
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from game.graphic import echo_test
#
# ModuleNotFoundError: No module named 'game'

# %%
import game
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import game
#
# ModuleNotFoundError: No module named 'game'
