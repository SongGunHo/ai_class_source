# %% [markdown]
# ## 사용자 정의 예외
# - Exception 클래스를 상속을 받으면 예외 클래스가 된다

# %%
class UserIdError(Exception):
    def __str__(self):
        return "아이디가 일치 하지 않습니다"

class UserPwError(Exception):

    def  __str__(self):
        return "비밀번호가 일치 하지 않습니다"

# %%
def login(user_id, user_pw):
    if user_id != "user01":
        raise UserIdError("아이디가 일치 하지 않습니다")
    if user_pw != '123456':
        raise UserPwError("비밀 번호가 일치 하지 않습니다")

# %%
try:
    login('user02', '123456')
except Exception as e:
    print(e)
# Out:
# 아이디가 일치 하지 않습니다
