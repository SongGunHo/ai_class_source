# %% [markdown]
# ##  클래스 내에 변수를 정의 하면?
# - 정적 변수
# - 객채를 생성 하지 않아도 클래스명으로 직접 접근 가능
# - 클래스에 정의 하지 않고 클래스명에 직접 대입 해도 가능

# %%
class Person:
    first_name='이름'
    last_name='김'

# %%
p1.last_name ='최' ## 인스턴스 변수  last_name에 할당

# %%
print("p1",p1.first_name , p1.last_name, Person.last_name )
print("p2",p2.first_name , p2.last_name, Person.last_name )
# Out:
# p1 이름 최 김
# p2 이름 김 김

# %%
p1 = Person()
p2 = Person()

# %%
print(p1.first_name , p1.last_name)
print(p2.first_name, p2.last_name)
# Out:
# 이름 김
# 이름 김

# %%
print(Person.first_name, Person.last_name)
# Out:
# 이름 김

# %%
Person.address='주소' # 정적 변수

# %%
p1.address
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 p1.address
#
# AttributeError: 'Person' object has no attribute 'address'

# %% [markdown]
# ## 클래스 상속
# ``` python
#
#     class 자식 클래스 (부모 클래스1, 부모클래스2 , ... ):
#         ...
#     ...
#
# ```
# - 다중 상속이 가능
