# %%
import numpy as np

fish_length = np.array ([25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0,
                31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0,
                35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0, 9.8,
                10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0])
fish_weight = np.array( [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0,
                500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0,
                700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0, 6.7,
                7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9] )

# %%
fish_data = np.column_stack((fish_length, fish_weight))
fish_target = np.concatenate((np.ones(35), np.zeros(14)))

# %%
from sklearn.model_selection import train_test_split

# %%
train_input , test_input, train_target, train_target = train_test_split(
    fish_data, fish_target, stratify=fish_target
)

# %%
from sklearn.preprocessing import StandardScaler

# %%
# fit (....) : 데이터 준비 ,  tranfrom (...) : 표준 점수 변환 작업 fit_transform(....)

ss = StandardScaler()
ss.fit(train_input)
# Out:
# StandardScaler()

# %%
tarain_scaled  = ss.transform(train_input)

test_scaled = ss.transform(test_input)

# %%
tarain_scaled[:5]
# Out:
# array([[ 0.79674429,  0.80972793],
#        [ 0.9978154 ,  1.73865037],
#        [ 1.24915429,  1.50641976],
#        [-0.16839706, -0.60842699],
#        [ 0.36444139,  0.1904463 ]])

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
kn = KNeighborsClassifier()

# %%
kn.fit(tarain_scaled, train_target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 kn.fit(tarain_scaled, train_target)
#
# File c:\Users\admin\Desktop\송근호\09.핀테크 머신 러닝과 딥런닝 이해\.venv\Lib\site-packages\sklearn\base.py:1363, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
# -> 1363     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\admin\Desktop\송근호\09.핀테크 머신 러닝과 딥런닝 이해\.venv\Lib\site-packages\sklearn\neighbors\_classification.py:239, in KNeighborsClassifier.fit(self, X, y)
#     217 @_fit_context(
#     218     # KNeighborsClassifier.metric is not validated yet
#     219     prefer_skip_nested_validation=False
# ...

# %%
fish  = ss.transform(np.array([[25. 150]]))
# Out:
#   Cell In[23], line 1
#     fish  = ss.transform(np.array([[25. 150]]))
#                                     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
kn.predict(fish)

# %%
import matplotlib.pyplot as plt
__, indexes = kn.kenighbors(fish)

plt.scatter(train_scaled[:, 0], train_scaled[indexes, 1], marker='D')
plt.scatter(fish[0][0], fish[0][1], marker='^')
plt.xlabel('length')
plt.ylabel('weigth')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 __, indexes = kn.kenighbors(fish)
#       4 plt.scatter(train_scaled[:, 0], train_scaled[indexes, 1], marker='D')
#       5 plt.scatter(fish[0][0], fish[0][1], marker='^')
#
# AttributeError: 'KNeighborsClassifier' object has no attribute 'kenighbors'
