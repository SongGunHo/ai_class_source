# %%
fish_length = [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0,
                31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0,
                35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0, 9.8,
                10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]
fish_weight = [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0,
                500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0,
                700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0, 6.7,
                7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]

# %%
fish_data = [[1, w]for l , w in zip(fish_length , fish_weight)]
fish_target = [1] * 35 + [0] *14

# %%
from sklearn.neighbors import KNeighborsClassifier
kn = KNeighborsClassifier

# %%
train_input = fish_data[:39] # 훈련 세트 입력 
train_target = fish_target[:39] # 훈련세트 타겟 입력 
test_input= fish_data[39:] # 테스트 세트 입력 테스트 
test_target = fish_target[39:] # 테스트 세트 타겟 테스트

# %%
kn.fit(train_input, train_target) # 훈련
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 kn.fit(train_input, train_target) # 훈련
#
# File c:\Users\admin\Desktop\송근호\09.핀테크 머신 러닝과 딥런닝 이해\.venv\Lib\site-packages\sklearn\base.py:1356, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1351 partial_fit_and_fitted = (
#    1352     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1353 )
#    1355 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
#    1363     return fit_method(estimator, *args, **kwargs)
#
# AttributeError: 'list' object has no attribute '_validate_params'

# %%
# 도미데이터로 학습하고 방어 데이터로 테스트 -> 샘플링 편향
kn.score(test_input, test_target)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # 도미데이터로 학습하고 방어 데이터로 테스트 -> 샘플링 편향
# ----> 2 kn.score(test_input, test_target)
#
# TypeError: KNeighborsClassifier.score() missing 1 required positional argument: 'y'
