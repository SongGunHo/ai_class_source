# %%
# 텐서플로 
# !pip install tensorflow
# Out:
# ...
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached typing_extensions-4.14.0-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached charset_normalizer-3.4.2-cp312-cp312-win_amd64.whl.metadata (36 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
#    ---------------------------------------- 0.0/376.0 MB ? eta -:--:--
#     --------------------------------------- 6.6/376.0 MB 36.8 MB/s eta 0:00:11
#    - -------------------------------------- 15.5/376.0 MB 39.0 MB/s eta 0:00:10
#    -- ------------------------------------- 20.7/376.0 MB 34.5 MB/s eta 0:00:11
#    -- ------------------------------------- 27.8/376.0 MB 33.9 MB/s eta 0:00:11
#    --- ------------------------------------ 34.3/376.0 MB 33.1 MB/s eta 0:00:11
#    ---- ----------------------------------- 40.9/376.0 MB 32.9 MB/s eta 0:00:11
#    ---- ----------------------------------- 43.5/376.0 MB 30.1 MB/s eta 0:00:12
# ...

# %%
# 파이토치 
# !pip install torch
# Out:
# ...
#    ---------------------------------------- 0.0/216.1 MB ? eta -:--:--
#    - -------------------------------------- 9.2/216.1 MB 47.7 MB/s eta 0:00:05
#    --- ------------------------------------ 21.0/216.1 MB 60.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 25.7/216.1 MB 42.8 MB/s eta 0:00:05
#    ------- -------------------------------- 38.0/216.1 MB 47.4 MB/s eta 0:00:04
#    --------- ------------------------------ 54.0/216.1 MB 52.9 MB/s eta 0:00:04
#    ------------- -------------------------- 70.8/216.1 MB 57.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 87.3/216.1 MB 60.6 MB/s eta 0:00:03
#    ------------------ --------------------- 98.6/216.1 MB 61.7 MB/s eta 0:00:02
#    ------------------ -------------------- 102.8/216.1 MB 55.1 MB/s eta 0:00:03
#    ------------------- ------------------- 107.7/216.1 MB 51.7 MB/s eta 0:00:03
#    ---------------------- ---------------- 126.6/216.1 MB 55.0 MB/s eta 0:00:02
# ...

# %%
# !pip install torchvision
# Out:
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 23.3 MB/s eta 0:00:00
# ...

# %%
import keras
import tensorflow as tf
