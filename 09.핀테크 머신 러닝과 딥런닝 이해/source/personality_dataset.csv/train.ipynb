# %%
import pandas as pd
df = pd.read_csv('personality_datasert.csv')
df.head()
# Out:
#    Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0               4.0         No                      4.0            6.0
# 1               9.0        Yes                      0.0            0.0
# 2               9.0        Yes                      1.0            2.0
# 3               0.0         No                      6.0            7.0
# 4               3.0         No                      9.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 13.0             5.0   Extrovert
# 1                       Yes                  0.0             3.0   Introvert
# 2                       Yes                  5.0             2.0   Introvert
# 3                        No                 14.0             8.0   Extrovert
# 4                        No                  8.0             5.0   Extrovert

# %%
data = wine[['alcohol', 'sugar', 'pH']].to_numpy()
target = wien['class'].to_numpy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 data = wine[['alcohol', 'sugar', 'pH']].to_numpy()
# ----> 2 target = wien['Class'].to_numpy()
#
# NameError: name 'wien' is not defined

# %%
import numpy as np

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

# %%
hgb = HistGradientBoostingClassifier(random_state=85)

# %%
from sklearn.model_selection import train_test_split
train_input, train_target, train_target, test_target = target_test_split(
    data, target, test_size=0.2, random_state=42
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 train_input, train_target, train_target, test_target = target_test_split(
#       3     data, target, test_size=0.2, random_state=42
#       4 )
#
# NameError: name 'target_test_split' is not defined

# %%
hgb.fit(train_input , train_target)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 hgb.fit(train_input , train_target)
#
# NameError: name 'train_input' is not defined

# %%
print('train_score:', np.mean(['t']) )
