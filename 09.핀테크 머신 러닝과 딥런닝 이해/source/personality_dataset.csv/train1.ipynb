# %%
import pandas as pd
df=pd.read_csv('personality_dataset.csv ')
df.head()
# Out:
#    Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0               4.0         No                      4.0            6.0
# 1               9.0        Yes                      0.0            0.0
# 2               9.0        Yes                      1.0            2.0
# 3               0.0         No                      6.0            7.0
# 4               3.0         No                      9.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 13.0             5.0   Extrovert
# 1                       Yes                  0.0             3.0   Introvert
# 2                       Yes                  5.0             2.0   Introvert
# 3                        No                 14.0             8.0   Extrovert
# 4                        No                  8.0             5.0   Extrovert

# %%
yes_no = {'Yes':1, 'No':0}
personality = {'Extrovert': 1, 'Introvert': 0}

# %%
df = df.replace(to_replace={'Stage_fear': yes_no, 'Drained_after_socializing': yes_no, 'Personality': personality})
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_15596\3101011837.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(to_replace={'Stage_fear': yes_no, 'Drained_after_socializing': yes_no, 'Personality': personality})

# %%
df = df.replace(to_replace={'Stage_fear': yes_no, 'Drained_after_socializing': yes_no, 'Personality': personality})

df.head()
# Out:
#    Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0               4.0         0.0                      4.0            6.0
# 1               9.0         1.0                      0.0            0.0
# 2               9.0         1.0                      1.0            2.0
# 3               0.0         0.0                      6.0            7.0
# 4               3.0         0.0                      9.0            4.0
#
#    Drained_after_socializing  Friends_circle_size  Post_frequency  Personality
# 0                        0.0                 13.0             5.0            1
# 1                        1.0                  0.0             3.0            0
# 2                        1.0                  5.0             2.0            0
# 3                        0.0                 14.0             8.0            1
# 4                        0.0                  8.0             5.0            1

# %%
personality_tatget[:10]

# %%
personality_target = df['Personality'].to_numpy()
personality_data = df.drop('Personality', axis=1).to_numpy()

# %%
personality_target[:10]
# Out:
# array([1, 0, 0, 1, 1, 1, 1, 1, 0, 1])

# %%
# 훈런세트 테스트 세트
from sklearn.model_selection import train_test_split, GridSearchCV
train_input, train_input, train_target, test_target = train_test_split(
     personality_data, personality_target, test_size=0.1, random_state=42
)

# %%
# 최적의 모델을 찾기!
from sklearn.ensemble import HistGradientBoostingClassifier
import numpy as np

params = {
    'max_iter': np.arange(90, 300, 10),
    'learning_rate': [0.0001, 0.001, 0.002, 0.003, 0.004, 0.005, 0.01],
}
gs = GridSearchCV(HistGradientBoostingClassifier(random_state=42), params, n_jobs=-1)
gs.fit(train_input, train_target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 10
#       5 params = {
#       6     'max_iter': np.arange(90, 300, 10),
#       7     'learning_rate': [0.0001, 0.001, 0.002, 0.003, 0.004, 0.005, 0.01],
#       8 }
#       9 gs = GridSearchCV(HistGradientBoostingClassifier(random_state=42), params, n_jobs=-1)
# ---> 10 gs.fit(train_input, train_target)
#
# File c:\Users\admin\Desktop\송근호\09.핀테크 머신 러닝과 딥런닝 이해\source\.venv\Lib\site-packages\sklearn\base.py:1363, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
# -> 1363     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\admin\Desktop\송근호\09.핀테크 머신 러닝과 딥런닝 이해\source\.venv\Lib\site-packages\sklearn\model_selection\_search.py:955, in BaseSearchCV.fit(self, X, y, **params)
#     952 estimator = self.estimator
#     953 scorers, refit_metric = self._get_scorers()
# --> 955 X, y = indexable(X, y)
#     956 params = _check_method_params(X, params=params)
#     958 routed_params = self._get_routed_params_for_fit(params)
#
# File c:\Users\admin\Desktop\송근호\09.핀테크 머신 러닝과 딥런닝 이해\source\.venv\Lib\site-packages\sklearn\utils\validation.py:530, in indexable(*iterables)
#     500 """Make arrays indexable for cross-validation.
#     501
#     502 Checks consistent length, passes through None, and ensures that everything
#    (...)    526 [[1, 2, 3], array([2, 3, 4]), None, <...Sparse...dtype 'int64'...shape (3, 1)>]
#     527 """
#     529 result = [_make_indexable(X) for X in iterables]
# --> 530 check_consistent_length(*result)
#     531 return result
#
# File c:\Users\admin\Desktop\송근호\09.핀테크 머신 러닝과 딥런닝 이해\source\.venv\Lib\site-packages\sklearn\utils\validation.py:473, in check_consistent_length(*arrays)
#     471 lengths = [_num_samples(X) for X in arrays if X is not None]
#     472 if len(set(lengths)) > 1:
# --> 473     raise ValueError(
#     474         "Found input variables with inconsistent numbers of samples: %r"
#     475         % [int(l) for l in lengths]
#     476     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [290, 2610]

# %%
np.mean(gs.cv_results_['mean_test_score'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 np.mean(gs.cv_results_['mean_test_score'])
#
# AttributeError: 'GridSearchCV' object has no attribute 'cv_results_'

# %%
gs.best_params_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 gs.best_params_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %%
hgb = gs.best_estimator_
print("학습세트:", hgb.score(train_input, train_target))
print("테스트세트:", hgb.score(test_input, test_target))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 hgb = gs.best_estimator_
#       2 print("학습세트:", hgb.score(train_input, train_target))
#       3 print("테스트세트:", hgb.score(test_input, test_target))
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator_'
