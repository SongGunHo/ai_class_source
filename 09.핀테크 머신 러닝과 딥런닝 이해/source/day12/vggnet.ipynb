# %%
import keras

# 
vggent = keras.applications.VGG16()

# %%
vggent.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ...

# %%
# !pip install pillow

# %%
# dog 이미지 불러오기
from PIL import Image

dog_png = Image.open("images/dog_png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 4
#       1 # dog 이미지 불러오기
#       2 from PIL import Image
# ----> 4 dog_png = Image.open("images/dog_png")
#
# File c:\Users\admin\Desktop\송근호\09.핀테크 머신 러닝과 딥런닝 이해\source\.venv\Lib\site-packages\PIL\Image.py:3505, in open(fp, mode, formats)
#    3502     filename = os.fspath(fp)
#    3504 if filename:
# -> 3505     fp = builtins.open(filename, "rb")
#    3506     exclusive_fp = True
#    3507 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images/dog_png'

# %%
# 사진 학습된 모델 마다 전처리 방법이 다르다 
import numpy as np
from keras.applications import vgg16
vgg_dog = vgg16.preprocess_input(np.array(dog_png))
#vgg_dog = vgg_dog(np.array(dog_png))
vgg_dog = vgg_dog[np.newaxis, :]
vgg_dog.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       2 import numpy as np
#       3 from keras.applications import vgg16
# ----> 4 vgg_dog = vgg16.preprocess_input(np.array(dog_png))
#       5 #vgg_dog = vgg_dog(np.array(dog_png))
#       6 vgg_dog = vgg_dog[np.newaxis, :]
#
# NameError: name 'dog_png' is not defined

# %%
prdeicvtions = vggent.predict(vgg_dog)
index = np.argmax(predicts, axis=1)
index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 prdeicvtions = vggent.predict(vgg_dog)
#       2 index = np.argmax(predicts, axis=1)
#       3 index
#
# NameError: name 'vgg_dog' is not defined

# %%
vgg16.decode_predictions(predictons)# 이미지넷 1000개 클래스 항목 출력
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 vgg16.decode_predictions(predictons)# 이미지넷 1000개 클래스 항목 출력
#
# NameError: name 'predictons' is not defined
