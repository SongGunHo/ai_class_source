# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

import time

dirver = webdriver.Chrome()
# 브라우저 주소창을 변경 하고 이동
dirver.get('https://www.naver.com')
time.sleep(3)

# %%
#search_box = dirver.find_element(By.ID , "query")
search_box = dirver.find_element(By.XPATH, "//form[@id='sform']/fieldset/div/input")
print(search_box)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="8e73a6a6876c9d740d14aa603205e613", element="f.0F6C725DD0CDF036486E0D1B2959646C.d.3F03C3DF815D766C50C4E2147768A029.e.4")>

# %%
#search_box.send_keys("블로그")

# %%
search_box.send_keys("블로그")
search_box.send_keys(Keys.ENTER) # 엔터키

# %%
#search_btn= dirver.find_element(By.CLASS_NAME, "btn_search")
#search_btn.click()

# %%
headile_section = dirver.find_ement
