# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome()
driver.get("https://news.naver.com/section/105")
time.sleep(3)

# %%
headline_section = driver.find_element(By.CLASS_NAME, 'as_headline')
headline_section
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2aa1b33ebed780331e032c66abbb1f1f", element="f.CFC34FD9F51A652BB6A2D2CB0D4D31B1.d.799EAFF2E637208C8CF64C392AFFABAE.e.79")>

# %%
items = headline_section.find_elements(By.CLASS_NAME, 'as_headline')

# %%
for item in items:
    print(item.text)

# %%
images = driver.find_elements(By.CSS_SELECTOR, ".as_headline .sa_thumb_link img")
images
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2aa1b33ebed780331e032c66abbb1f1f", element="f.CFC34FD9F51A652BB6A2D2CB0D4D31B1.d.799EAFF2E637208C8CF64C392AFFABAE.e.18")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2aa1b33ebed780331e032c66abbb1f1f", element="f.CFC34FD9F51A652BB6A2D2CB0D4D31B1.d.799EAFF2E637208C8CF64C392AFFABAE.e.19")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2aa1b33ebed780331e032c66abbb1f1f", element="f.CFC34FD9F51A652BB6A2D2CB0D4D31B1.d.799EAFF2E637208C8CF64C392AFFABAE.e.20")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2aa1b33ebed780331e032c66abbb1f1f", element="f.CFC34FD9F51A652BB6A2D2CB0D4D31B1.d.799EAFF2E637208C8CF64C392AFFABAE.e.21")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2aa1b33ebed780331e032c66abbb1f1f", element="f.CFC34FD9F51A652BB6A2D2CB0D4D31B1.d.799EAFF2E637208C8CF64C392AFFABAE.e.22")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2aa1b33ebed780331e032c66abbb1f1f", element="f.CFC34FD9F51A652BB6A2D2CB0D4D31B1.d.799EAFF2E637208C8CF64C392AFFABAE.e.23")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2aa1b33ebed780331e032c66abbb1f1f", element="f.CFC34FD9F51A652BB6A2D2CB0D4D31B1.d.799EAFF2E637208C8CF64C392AFFABAE.e.24")>]

# %%
from urllib.request import urlretrieve

for i, image in enumerate(images):
    image_url = image.get_attribute('src')
    urlretrieve(image_url, f"C:/uploads/{i}.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 5
#       3 for i, image in enumerate(images):
#       4     image_url = image.get_attribute('src')
# ----> 5     urlretrieve(image_url, f"C:/uploads/{i}.jpg")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:250, in urlretrieve(url, filename, reporthook, data)
#     248 # Handle temporary file setup.
#     249 if filename:
# --> 250     tfp = open(filename, 'wb')
#     251 else:
#     252     tfp = tempfile.NamedTemporaryFile(delete=False)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/uploads/0.jpg'

# %%
from bs4 import BeautifulSoup as bs

html =dirver.page_source
soup = bs(html, 'html.parser')

# %%
# 자바 스크립트 실행 
dirver.execute_script("alert('자바 스크립트 실행')")
