# %%
import numpy as np
fruits = np.array(['사과' , '오렌지', '바나나','맬론 ','망고'])

# %%
fruits[[False, True, True ,False, False]]
# Out:
# array(['오렌지', '바나나'], dtype='<U3')

# %%
fruits[[0,1,2]]
# Out:
# array(['사과', '오렌지', '바나나'], dtype='<U3')

# %%
import matplotlib.pyplot as plt

# %%
x = np.arange(-1000, 1,0.1)
y = 1  / (1 + np.exp(-x))
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_16364\1136910709.py:2: RuntimeWarning: overflow encountered in exp
#   y = 1  / (1 + np.exp(-x))

# %%
plt.plot(x,y)
plt.plot('x')
plt.plot('y')
plt.show()
